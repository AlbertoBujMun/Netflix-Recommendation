# %%
import pandas as pd

# %%
movies_0_2 = pd.read_csv("cooked_movie_data_0kto2k.csv").set_index('id')
movies_2_4 = pd.read_csv("cooked_movie_data_2kto4k.csv").set_index('id')
movies_4_6 = pd.read_csv("cooked_movie_data_4kto6k.csv").set_index('id')
movies_6_8 = pd.read_csv("cooked_movie_data_6kto8k.csv").set_index('id')
movies_8_10 = pd.read_csv("cooked_movie_data_8kto10k.csv").set_index('id')
movies_10_12 = pd.read_csv("cooked_movie_data_10_12.csv").set_index('id')
movies_12_14 = pd.read_csv("cooked_movie_data_12_14.csv").set_index('id')
movies_14_16 = pd.read_csv("cooked_movie_data_14_16.csv").set_index('id')
movies_16_18 = pd.read_csv("cooked_movie_data_16_18.csv").set_index('id')

# %%
movies=pd.concat([movies_0_2, movies_2_4,movies_4_6,movies_6_8,movies_8_10,movies_10_12,movies_12_14,movies_14_16,movies_16_18])
movies.to_csv("final_data/cooked_movies.csv")

# %%
cooked_movies = pd.read_csv("cooked_movies.csv").set_index('id')
cooked_movies.tail()
# Out:
#          year                                              title  Runtime  \
# id
# 17766  2002.0  Where the Wild Things Are and Other Maurice Se...      NaN
# 17767  2004.0                  Fidel Castro: American Experience      NaN
# 17768  2000.0                                              Epoch      NaN
# 17769  2003.0                                        The Company    112.0
# 17770  2003.0                                       Alien Hunter     92.0
#
#        Rating      Directors                                      Writers  \
# id
# 17766     NaN            NaN                                          NaN
# 17767     NaN            NaN                                          NaN
# 17768     6.9    Vincent Lee                                  David Tzeng
# 17769     6.4  Robert Altman  Neve Campbell-Barbara Turner-Barbara Turner
# 17770     5.1     Ron Krauss      J.S. Cardone-Boaz Davidson-J.S. Cardone
#
#                                     Production companies  \
# id
# ...
