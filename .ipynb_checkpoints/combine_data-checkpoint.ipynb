# %%
import pandas as pd

# To do linear algebra
import numpy as np

# %%
#We load the movies for the combination
movies = pd.read_csv("final_data/cooked_movies.csv").set_index('id')
movies.head()

# %%
#We pick 10 random users for the test, we are going to store their models and consul those when needed
#usr_list=['30878','1989766','14756','2380848','2161335','956464','1050889','584301','52736','2113696']
usr_list=['30878']
#We now choose a list with our combined data files to use
#files_list=['combined_data_1.txt','combined_data_2.txt','combined_data_3.txt','combined_data_4.txt']
files_list=['combined_data_1.txt']

# %%
print("Commencing file processing")
for user in usr_list:
    i=0
    print("processing user " + user)
    usr_ratings = []
    for filename in files_list:
        print("processing file " + filename)
        with open("data/"+filename) as infile:
            for line in infile:
                if ":" in line:
                    #Here a new film starts to process
                    if i !=0:
                        movie_rate = np.array([i,rate])
                        usr_ratings.append(movie_rate)
                        rate = None        
                    i=int(line.replace(":",""))
                elif ":" not in line:
                    split = line.split(",")
                    usr = split[0]
                    if(usr==user):
                        rate = float(split[1])
        usr_ratings = np.asarray(usr_ratings)
        df = pd.DataFrame(data=usr_ratings, columns=['id','rating'])
        df.rating = df.rating.astype('float')
        df.id = df.id.astype('int')
        df = df.set_index('id')
# Out:
# Commencing file processing
# processing user 30878
# processing file combined_data_1.txt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_blocks(blocks, axes)
#    4858
# -> 4859         mgr = BlockManager(blocks, axes)
#    4860         mgr._consolidate_inplace()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in __init__(self, blocks, axes, do_integrity_check)
#    3281         if do_integrity_check:
# -> 3282             self._verify_integrity()
#    3283
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in _verify_integrity(self)
#    3492             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 3493                 construction_error(tot_items, block.shape[1:], self.axes)
#    3494         if len(self.items) != tot_items:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in construction_error(tot_items, block_shape, axes, e)
#    4842     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4843         passed, implied))
#    4844
#
# ValueError: Shape of passed values is (2, 4498), indices imply (2, 1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-4e455e67a874> in <module>
#      21                         rate = float(split[1])
#      22         usr_ratings = np.asarray(usr_ratings)
# ---> 23         df = pd.DataFrame(data=usr_ratings, columns=['movie','rating'],index=['movie'])
#      24         df.head()
#      25
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     377             else:
#     378                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 379                                          copy=copy)
#     380         elif isinstance(data, (list, types.GeneratorType)):
#     381             if isinstance(data, types.GeneratorType):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     534             values = maybe_infer_to_datetimelike(values)
#     535
# --> 536         return create_block_manager_from_blocks([values], [columns, index])
#     537
#     538     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_blocks(blocks, axes)
#    4864         blocks = [getattr(b, 'values', b) for b in blocks]
#    4865         tot_items = sum(b.shape[0] for b in blocks)
# -> 4866         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    4867
#    4868
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in construction_error(tot_items, block_shape, axes, e)
#    4841         raise ValueError("Empty data passed with indices specified.")
#    4842     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4843         passed, implied))
#    4844
#    4845
#
# ValueError: Shape of passed values is (2, 4498), indices imply (2, 1)

# %%
df = pd.DataFrame(data=usr_ratings, columns=['id','rating'])
df.rating = df.rating.astype('float')
df.id = df.id.astype('int')
df = df.set_index('id')
df.head()
# Out:
#     rating
# id
# 1      4.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5      1.0

# %%
# Out:
#       year                         title  Runtime  Rating  \
# id
# 1   2003.0               Dinosaur Planet     50.0     7.7
# 2   2004.0    Isle of Man TT 2004 Review      NaN     NaN
# 3   1997.0                     Character    122.0     7.8
# 4   1994.0  Paula Abdul's Get Up & Dance     54.0     8.8
# 5   2004.0      The Rise and Fall of ECW    360.0     8.6
#
#               Directors                                          Writers  \
# id
# 1   Pierre de Lespinois           Mike Carrol-Mike Carroll-Georgann Kane
# 2                   NaN                                              NaN
# 3         Mike van Diem  Ferdinand Bordewijk-Laurens Geels-Mike van Diem
# 4         Steve Purcell                                              NaN
# 5            Kevin Dunn                                      Paul Heyman
#
#                   Production companies                        Genres
# id
# 1                                  NaN  Documentary-Animation-Family
# 2                                  NaN                           NaN
# 3   First Floor Features-Almerica Film           Crime-Drama-Mystery
# 4                                  NaN                        Family
# 5                       WWE Home Video             Documentary-Sport

# %%
dfs = movies.join(df)
dfs.head()
# Out:
#       year                         title  Runtime  Rating  \
# id
# 1   2003.0               Dinosaur Planet     50.0     7.7
# 2   2004.0    Isle of Man TT 2004 Review      NaN     NaN
# 3   1997.0                     Character    122.0     7.8
# 4   1994.0  Paula Abdul's Get Up & Dance     54.0     8.8
# 5   2004.0      The Rise and Fall of ECW    360.0     8.6
#
#               Directors                                          Writers  \
# id
# 1   Pierre de Lespinois           Mike Carrol-Mike Carroll-Georgann Kane
# 2                   NaN                                              NaN
# 3         Mike van Diem  Ferdinand Bordewijk-Laurens Geels-Mike van Diem
# 4         Steve Purcell                                              NaN
# 5            Kevin Dunn                                      Paul Heyman
#
#                   Production companies                        Genres  rating
# id
# 1                                  NaN  Documentary-Animation-Family     4.0
# 2                                  NaN                           NaN     NaN
# 3   First Floor Features-Almerica Film           Crime-Drama-Mystery     NaN
# 4                                  NaN                        Family     NaN
# 5                       WWE Home Video             Documentary-Sport     1.0
